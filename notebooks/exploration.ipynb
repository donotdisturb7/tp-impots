# %%
# Imports nécessaires
import sys
import os
sys.path.append('..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# Imports des modèles
from models.individual import IndividualTaxCalculator
from models.ode_model import ODEPopulationModel
from models.markov_model import MarkovPopulationModel
from utils.bareme import get_bareme_2024
from utils.visualization import (
    create_tax_plots, create_population_plots, 
    create_comparison_plots, create_barème_plot
)

# Configuration des graphiques
plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = (12, 8)

print("Modules importés avec succès!")
# Out:
# Modules importés avec succès!

# %% [markdown]
# ## 1. Test du Calculateur Individuel
# """

# %%
# Initialisation du calculateur
calculator = IndividualTaxCalculator()

# Test avec différents revenus
revenus_test = [15000, 25000, 35000, 50000, 80000, 120000, 200000]
resultats = []

for revenu in revenus_test:
    resultat = calculator.calculer_impot_complet(revenu, 1.0)
    resultats.append({
        'revenu': revenu,
        'impot_net': resultat['impot_net'],
        'taux_effectif': resultat['taux_effectif'],
        'taux_marginal': resultat['taux_marginal'],
        'taux_moyen': resultat['taux_moyen']
    })

df_resultats = pd.DataFrame(resultats)
print("Résultats du calculateur individuel:")
print(df_resultats.round(4))
# Out:
# Résultats du calculateur individuel:
#    revenu   impot_net  taux_effectif  taux_marginal  taux_moyen
# 0   15000      0.0000         0.0000           0.11      0.0257
# 1   25000   1403.3275         0.0561           0.11      0.0594
# 2   35000   3665.6700         0.1047           0.30      0.1047
# 3   50000   8165.6700         0.1633           0.30      0.1633
# 4   80000  17165.6700         0.2146           0.30      0.2146
# 5  120000  33145.3600         0.2762           0.41      0.2762
# 6  200000  66733.7200         0.3337           0.45      0.3337
